# %% [markdown]
# <a href="https://colab.research.google.com/github/HardikB16/Datasets/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");
print(fields)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
## This returns the count of all NA values in each column
fields.isna().sum()
# Out:
# Prefix        0
# Assignment    3
# Tutorial      4
# Midterm       4
# TakeHome      4
# Final         7
# dtype: int64

# %%
## Check if any 2 column out of N list have NAN values for more a single row

fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");
countofNAN_onrow = fields.isna().sum(axis = 1)
indexofrow = countofNAN_onrow[countofNAN_onrow >=2].index
print(indexofrow)
print(fields.loc[indexofrow])
# Out:
# Index([47, 54, 56, 83], dtype='int64')
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 47       8       85.01       NaN      NaN     83.33    NaN
# 54       8         NaN    102.87      NaN     21.53  36.11
# 56       8         NaN    106.53     37.5       NaN    NaN
# 83       4       86.86       NaN     92.5       NaN    NaN

# %%
## Creates a new dataframe and then checks if the column values are NAN of not
newdf = fields.dropna(axis = 0 , subset= ["Assignment","Midterm"], how = "any");
newdf.count()
# Out:
# Prefix        93
# Assignment    93
# Tutorial      90
# Midterm       93
# TakeHome      90
# Final         88
# dtype: int64

# %%
# Alters the existing dataframe with deleted values.
fields.dropna(axis = 0 , subset= ["Assignment","Midterm"], how = "any", inplace = True);
fields.count()
# Out:
# Prefix        93
# Assignment    93
# Tutorial      90
# Midterm       93
# TakeHome      90
# Final         88
# dtype: int64

# %%
# Reading again as the one above is altered

fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");
print(fields)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
## Filling nAN values with default values
fields.fillna(value = 0,inplace = True)
fields.isna().sum()
# Out:
# Prefix        0
# Assignment    0
# Tutorial      0
# Midterm       0
# TakeHome      0
# Final         0
# dtype: int64

# %%
## Populating mean for the each column in the dataframe in place of nan
fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");
fields.fillna(value = fields.mean(),inplace = True)
fields.notna().sum()
# Out:
# Prefix        99
# Assignment    99
# Tutorial      99
# Midterm       99
# TakeHome      99
# Final         99
# dtype: int64

# %%
print(fields.mean())
# Out:
# Prefix         7.313131
# Assignment    85.541042
# Tutorial      90.160105
# Midterm       67.197684
# TakeHome      80.408211
# Final         68.668478
# dtype: float64

# %%
## Populating mean for the each column in the dataframe in place of nan
fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");
fields.fillna(value = fields.mean(),inplace = True)
fields.notna().sum()
# Out:
# Prefix        99
# Assignment    99
# Tutorial      99
# Midterm       99
# TakeHome      99
# Final         99
# dtype: int64

# %%
## Fill different columns with different values
fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");
set = {"Assignment" : fields["Assignment"].mean(),
       "Tutorial"   : fields["Tutorial"].median(),
       "TakeHome"   : 0}

fields.fillna(value = set, inplace = True)
fields.notna().sum()
# Out:
# Prefix        99
# Assignment    99
# Tutorial      99
# Midterm       95
# TakeHome      99
# Final         92
# dtype: int64

# %%
## Fill columns with default values with more columns
fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");

for col in fields.columns:
    fields[col].fillna(value = fields[col].mean(), inplace = True)

fields.isna().sum()
# Out:
# Prefix        0
# Assignment    0
# Tutorial      0
# Midterm       0
# TakeHome      0
# Final         0
# dtype: int64

# %%
print(fields.head())
print(fields.tail())
print(fields.shape)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17    30.00     63.15  48.89
# 3       7       81.22     96.06    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
# (99, 6)

# %%
fields.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prefix      99 non-null     int64
#  1   Assignment  99 non-null     float64
#  2   Tutorial    99 non-null     float64
#  3   Midterm     99 non-null     float64
#  4   TakeHome    99 non-null     float64
#  5   Final       99 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.8 KB

# %%
##

fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");
print(fields.isna().any(axis=1))
fields[fields.isna().all(axis=1)]
fields[fields.isna().any(axis=1)]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Length: 99, dtype: bool
#     Prefix  Assignment  Tutorial  Midterm  TakeHome   Final
# 7        7       72.85     86.85    60.00       NaN   56.11
# 20       8       63.40     86.21    63.12     72.78     NaN
# 38       6       90.74     89.64    61.25     90.00     NaN
# 47       8       85.01       NaN      NaN     83.33     NaN
# 54       8         NaN    102.87      NaN     21.53   36.11
# 56       8         NaN    106.53    37.50       NaN     NaN
# 58       8       68.95       NaN    40.00     57.41   78.89
# 60       8       71.79    102.87    41.88     24.77     NaN
# 64       7       91.28    108.71    96.25       NaN   88.89
# 67       8         NaN    100.58    54.37     63.89   63.89
# 68       7      100.83    105.57      NaN    104.44  108.89
# 71       8       93.59    103.83    92.50     96.85     NaN
# ...

# %%
print(fields[fields["Assignment"].isna() | fields["Tutorial"].isna()])
print(fields[fields["Assignment"].isna() ^ fields["Tutorial"].isna()])
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 47       8       85.01       NaN      NaN     83.33    NaN
# 54       8         NaN    102.87      NaN     21.53  36.11
# 56       8         NaN    106.53    37.50       NaN    NaN
# 58       8       68.95       NaN    40.00     57.41  78.89
# 67       8         NaN    100.58    54.37     63.89  63.89
# 80       8       81.22       NaN    79.38    105.93  90.00
# 83       4       86.86       NaN    92.50       NaN    NaN
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 47       8       85.01       NaN      NaN     83.33    NaN
# 54       8         NaN    102.87      NaN     21.53  36.11
# 56       8         NaN    106.53    37.50       NaN    NaN
# 58       8       68.95       NaN    40.00     57.41  78.89
# 67       8         NaN    100.58    54.37     63.89  63.89
# 80       8       81.22       NaN    79.38    105.93  90.00
# 83       4       86.86       NaN    92.50       NaN    NaN

# %%
## Isolating rows for use
fields[fields.index.isin(range(2,4))]
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 2       8       83.70     83.17    30.00     63.15  48.89
# 3       7       81.22     96.06    49.38    105.93  80.56

# %%
print(fields.loc[3])
print(fields.iloc[3])
# Out:
# Prefix          7.00
# Assignment     81.22
# Tutorial       96.06
# Midterm        49.38
# TakeHome      105.93
# Final          80.56
# Name: 3, dtype: float64
# Prefix          7.00
# Assignment     81.22
# Tutorial       96.06
# Midterm        49.38
# TakeHome      105.93
# Final          80.56
# Name: 3, dtype: float64

# %%
print(fields.loc[12:14])
print(fields.iloc[12:14])
print(fields.loc[[12, 14]])
print(fields.iloc[[12, 14]])
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 12       8       97.16    103.71    72.50     93.52  63.33
# 13       7       91.28     83.53    81.25     99.81  92.22
# 14       8       84.80     89.08    44.38     16.91  35.83
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 12       8       97.16    103.71    72.50     93.52  63.33
# 13       7       91.28     83.53    81.25     99.81  92.22
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 12       8       97.16    103.71    72.50     93.52  63.33
# 14       8       84.80     89.08    44.38     16.91  35.83
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 12       8       97.16    103.71    72.50     93.52  63.33
# 14       8       84.80     89.08    44.38     16.91  35.83

# %%
print(fields.loc[12:,["Assignment","Midterm"]])
print(fields.iloc[12:, [1,3,4]])
# Out:
#     Assignment  Midterm
# 12       97.16    72.50
# 13       91.28    81.25
# 14       84.80    44.38
# 15       93.83    88.12
# 16       84.80    47.50
# ..         ...      ...
# 94       96.73    45.00
# 95       85.34    41.25
# 96       89.94    87.50
# 97       95.60    66.25
# 98       63.40    73.12
#
# [87 rows x 2 columns]
#     Assignment  Midterm  TakeHome
# 12       97.16    72.50     93.52
# 13       91.28    81.25     99.81
# 14       84.80    44.38     16.91
# 15       93.83    88.12     80.93
# 16       84.80    47.50     16.91
# ..         ...      ...       ...
# 94       96.73    45.00     93.52
# 95       85.34    41.25     93.70
# 96       89.94    87.50     90.74
# 97       95.60    66.25     99.81
# 98       63.40    73.12     72.78
#
# [87 rows x 3 columns]

# %%
fields[fields.isna().sum(axis = 1) > 1]
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 47       8       85.01       NaN      NaN     83.33    NaN
# 54       8         NaN    102.87      NaN     21.53  36.11
# 56       8         NaN    106.53     37.5       NaN    NaN
# 83       4       86.86       NaN     92.5       NaN    NaN

# %%
fields[fields.Final >= 70]
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome   Final
# 3        7       81.22     96.06    49.38    105.93   80.56
# 4        8       91.32     93.64    95.00    107.41   73.89
# 11       6       86.26     80.60    74.38     87.59   77.50
# 13       7       91.28     83.53    81.25     99.81   92.22
# 15       7       93.83     95.43    88.12     80.93   90.00
# 19       8       93.04     82.93    79.38     83.33   91.11
# 23       7       80.44     90.20    46.25     91.48   72.22
# 25       6       91.28     95.24    82.50     97.59   92.78
# 26       8       82.45     86.65    93.12     85.56   89.17
# 27       8       75.27     86.67    69.38     61.11   88.89
# 28       8       91.32     94.89    76.25    107.41   85.56
# 33       7       98.58     91.03   101.25    104.26  107.78
# 39       7       95.00     94.36    89.38    100.93   85.00
# 41       7       95.14     82.67   110.00     89.81   90.83
# 42       7       92.01    112.58    86.25     86.11   83.33
# ...

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 's', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})

print(df)

df.drop_duplicates(inplace = True, subset= ["brand","style"])

print(df)

df.rename(columns = {"brand" : "br", "rating" : "ratings"},inplace = True)
print(df)
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum     s     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum     s     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
#         br style  ratings
# 0  Yum Yum   cup      4.0
# 1  Yum Yum     s      4.0
# 2  Indomie   cup      3.5
# 3  Indomie  pack     15.0

# %%
fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");
print(format(fields["Assignment"].mean(),".4f"))
print(round(fields["Assignment"].mean(),5))
# Out:
# 85.5410
# 85.54104

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie',np.nan, 'Indomie',np.nan,"Yum"],
    'style': ['cup', 's', 'cup', 'pack', 'pack',"sddd","sdddd","sddddd","sdddddd"],
    'rating': [4, 4, 3.5, 15, 5,4,4,4,5]
})

print(df["brand"].nunique())
print(df["brand"].unique())

print(df.value_counts(subset = ["brand"], dropna = False))
print('\n')
print(df.value_counts(subset = ["brand"], dropna = True))
print('\n')
print(df.value_counts(subset = ["brand"], dropna = False, normalize = 1))
print('\n')
print(df.value_counts(subset = ["brand"], dropna = 1, normalize = 1))
# Out:
# 3
# ['Yum Yum' 'Indomie' nan 'Yum']
# brand
# Indomie    4
# Yum Yum    2
# NaN        2
# Yum        1
# Name: count, dtype: int64
#
#
# brand
# Indomie    4
# Yum Yum    2
# Yum        1
# Name: count, dtype: int64
#
#
# brand
# Indomie    0.444444
# Yum Yum    0.222222
# NaN        0.222222
# Yum        0.111111
# Name: proportion, dtype: float64
#
#
# brand
# Indomie    0.571429
# Yum Yum    0.285714
# Yum        0.142857
# Name: proportion, dtype: float64

# %%
fields =  pd.read_csv("/content/sample_data/class-grades (1).csv",on_bad_lines = "warn");

fields["Final Result"] = np.where((fields["Final"] >= 70) | (fields["Tutorial"] >= 70),"Pass","Fail") #Tutorial	Midterm	TakeHome	Final
print(fields)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final Final Result
# 0        5       57.14     34.09    64.38     51.48  52.50         Fail
# 1        8       95.05    105.49    67.50     99.07  68.33         Pass
# 2        8       83.70     83.17    30.00     63.15  48.89         Pass
# 3        7       81.22     96.06    49.38    105.93  80.56         Pass
# 4        8       91.32     93.64    95.00    107.41  73.89         Pass
# ..     ...         ...       ...      ...       ...    ...          ...
# 94       8       96.73    103.71    45.00     93.52  61.94         Pass
# 95       7       85.34     80.54    41.25     93.70  39.72         Pass
# 96       8       89.94    102.77    87.50     90.74  87.78         Pass
# 97       7       95.60     76.13    66.25     99.81  85.56         Pass
# 98       8       63.40     97.37    73.12     72.78  77.22         Pass
#
# [99 rows x 7 columns]

# %%
fields["Final Result"] = np.where((fields["Assignment"] >= 70) & (fields["Final Result"] != "Pass"),"Pass In Assignnent only",fields["Final Result"]) \

fields["Final Result"].value_counts(dropna = 1 , normalize = 1)
# Out:
# Final Result
# Pass                       0.878788
# Pass In Assignnent only    0.080808
# Fail                       0.040404
# Name: proportion, dtype: float64

# %%
fields = fields[(fields["Final Result"] == "Pass") | (fields["Final Result"] == "Pass In Assignnent only")]
print(fields)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final Final Result
# 1        8       95.05    105.49    67.50     99.07  68.33         Pass
# 2        8       83.70     83.17    30.00     63.15  48.89         Pass
# 3        7       81.22     96.06    49.38    105.93  80.56         Pass
# 4        8       91.32     93.64    95.00    107.41  73.89         Pass
# 5        7       95.00     92.58    93.12     97.78  68.06         Pass
# ..     ...         ...       ...      ...       ...    ...          ...
# 94       8       96.73    103.71    45.00     93.52  61.94         Pass
# 95       7       85.34     80.54    41.25     93.70  39.72         Pass
# 96       8       89.94    102.77    87.50     90.74  87.78         Pass
# 97       7       95.60     76.13    66.25     99.81  85.56         Pass
# 98       8       63.40     97.37    73.12     72.78  77.22         Pass
#
# [95 rows x 7 columns]

# %%
df["Indexs"] = range(0,len(df))
print(df)
# Out:
#      brand    style  rating  Indexs
# 0  Yum Yum      cup     4.0       0
# 1  Yum Yum        s     4.0       1
# 2  Indomie      cup     3.5       2
# 3  Indomie     pack    15.0       3
# 4  Indomie     pack     5.0       4
# 5      NaN     sddd     4.0       5
# 6  Indomie    sdddd     4.0       6
# 7      NaN   sddddd     4.0       7
# 8      Yum  sdddddd     5.0       8

# %% [markdown]
# Stack Overflow Annual Developer Survey

# %%
survey = pd.read_csv("/content/sample_data/survey_results_public.csv")
print(survey.columns)
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
countrylist = ["Austria","India"]
survey.loc[(survey["ConvertedCompYearly"] > survey["ConvertedCompYearly"].mean()) & (survey["Country"].isin(countrylist)) ,("ConvertedCompYearly","Country")]
# Out:
#        ConvertedCompYearly  Country
# 498               117798.0  Austria
# 853               182052.0  Austria
# 2755              128507.0  Austria
# 3662              117798.0  Austria
# 4478              117798.0  Austria
# ...                    ...      ...
# 86252             135709.0    India
# 86268             339273.0    India
# 86626             104948.0  Austria
# 87267             112444.0  Austria
# 89144             128507.0  Austria
#
# [121 rows x 2 columns]

# %%
survey.loc[0:,("ConvertedCompYearly","LanguageHaveWorkedWith")]
# Out:
#        ConvertedCompYearly                             LanguageHaveWorkedWith
# 0                      NaN                                                NaN
# 1                 285000.0                         HTML/CSS;JavaScript;Python
# 2                 250000.0                         Bash/Shell (all shells);Go
# 3                 156000.0  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 4                  23456.0                     HTML/CSS;JavaScript;TypeScript
# ...                    ...                                                ...
# 89179                  NaN            HTML/CSS;Java;JavaScript;SQL;TypeScript
# 89180                  NaN                               Dart;Java;Python;SQL
# 89181                  NaN  Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89182                  NaN  Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 89183                  NaN                    C#;Go;JavaScript;SQL;TypeScript
#
# [89184 rows x 2 columns]

# %%
survey.loc[(survey["Country"] == "India"),("Country")] = "Ind"
print(survey["Country"].value_counts())
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# Ind                                                      5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
survey.loc[survey["LanguageHaveWorkedWith"].str.lower().str.contains("python",na= False),("ConvertedCompYearly","LanguageHaveWorkedWith")]
# Out:
#        ConvertedCompYearly                             LanguageHaveWorkedWith
# 1                 285000.0                         HTML/CSS;JavaScript;Python
# 7                  80000.0  Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 9                      NaN     HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 10                     NaN                  C#;C++;HTML/CSS;JavaScript;Python
# 11                 78003.0  C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
# ...                    ...                                                ...
# 89172                  NaN  Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89176                  NaN  HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89180                  NaN                               Dart;Java;Python;SQL
# 89181                  NaN  Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89182                  NaN  Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
#
# [43158 rows x 2 columns]

# %%
survey.loc[(survey["Country"] == "Ind"),("Country")] = survey["Country"].str.lower()
print(survey["Country"].value_counts())
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# ind                                                      5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
def uppercase(email) :
  return str(email).upper()

survey.loc[(survey["Country"] == "Canada"),("Country")] = survey["Country"].apply(uppercase)

print(survey["Country"].value_counts())
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# ind                                                      5625
# United Kingdom of Great Britain and Northern Ireland     5552
# CANADA                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
survey.loc[(survey["Country"] == "Germany"),("Country")] = survey["Country"].apply(lambda x: x.lower() if type(x) == str else x)

print(survey["Country"].value_counts())
# Out:
# Country
# United States of America                                18647
# germany                                                  7328
# ind                                                      5625
# United Kingdom of Great Britain and Northern Ireland     5552
# CANADA                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
survey.apply(len,axis = 1)
# Out:
# 0        86
# 1        86
# 2        86
# 3        86
# 4        86
#          ..
# 89179    86
# 89180    86
# 89181    86
# 89182    86
# 89183    86
# Length: 89184, dtype: int64

# %%
survey.applymap(lambda x: len(x) if type(x) == str else (0 if pd.isna(x) else x))
# Out:
#        ResponseId  Q120  MainBranch  Age  Employment  RemoteWork  \
# 0               1     7          13   15           0           0
# 1               2     7          30   15          19           6
# 2               3     7          30   15          19          36
# 3               4     7          30   15          19          36
# 4               5     7          30   15          72           6
# ...           ...   ...         ...  ...         ...         ...
# 89179       89180     7          30   15          72           6
# 89180       89181     7          30   15          38          36
# 89181       89182     7          27   17          19           0
# 89182       89183     7          30   18          38          36
# 89183       89184     7          30   15          19          36
#
#        CodingActivities  EdLevel  LearnCode  LearnCodeOnline  ...  \
# 0                     0        0          0                0  ...
# ...

# %%
survey = pd.read_csv("/content/sample_data/survey_results_public.csv")

# %%
survey.rename(columns={"ConvertedCompYearly":"SalaryUSDYearly"},inplace = 1)
print(survey["SalaryUSDYearly"])
# Out:
# 0             NaN
# 1        285000.0
# 2        250000.0
# 3        156000.0
# 4         23456.0
#            ...
# 89179         NaN
# 89180         NaN
# 89181         NaN
# 89182         NaN
# 89183         NaN
# Name: SalaryUSDYearly, Length: 89184, dtype: float64

# %%
people = {
    'first': ['Corey', 'Jane', 'John'],
    'last': ['Schafer', 'Doe', 'Doe'],
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}


df = pd.DataFrame(people)

print(df)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df["Full Name"] = df["first"] + " " + df["last"]
print(df)
# Out:
#    first     last                    email      Full Name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %%
df.drop(columns = {"first","last"}, inplace = True)
print(df)
# Out:
#                      email      Full Name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
print(df["Full Name"].str.split(" ",expand = True))

df[["First","Last"]] = df["Full Name"].str.split(" ",expand = True)

print(df)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe
#                      email      Full Name  First     Last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %%
people2 = {
    'first': ['Steve', 'Bruce'],
    'last': ['Rogers', 'Banner'],
    'email': ['SteveRogers@gmail.com', 'BruceBanner@email.com']
}

df2 = pd.DataFrame(people2)
print(df2)
# Out:
#    first    last                  email
# 0  Steve  Rogers  SteveRogers@gmail.com
# 1  Bruce  Banner  BruceBanner@email.com

# %%
newdf = pd.concat([df,df2], ignore_index = True)

print(newdf)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3  Steve   Rogers    SteveRogers@gmail.com
# 4  Bruce   Banner    BruceBanner@email.com

# %%
newdf.drop(index = newdf[newdf["last"] == "Doe"].index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-330-56a2a694a3e9> in <cell line: 1>()
# ----> 1 newdf.drop(index = newdf[newdf["last"] == "Doe"].index, inplace = 1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4527         errors: IgnoreRaise = "raise",
#    4528     ) -> NDFrameT | None:
# -> 4529         inplace = validate_bool_kwarg(inplace, "inplace")
#    4530
#    4531         if labels is not None:
#
# ...

# %%
newdf.sort_values(by = ["last"], ascending = True)
# Out:
#    first     last                    email
# 4  Bruce   Banner    BruceBanner@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3  Steve   Rogers    SteveRogers@gmail.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
newdf.sort_values(by = ["last","first"], ascending = [True,False])
# Out:
#    first     last                    email
# 4  Bruce   Banner    BruceBanner@email.com
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 3  Steve   Rogers    SteveRogers@gmail.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
newdf.sort_values(by = ["last","first"], ascending = [True,False], inplace = True)
print(newdf)
# Out:
#    first     last                    email
# 4  Bruce   Banner    BruceBanner@email.com
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 3  Steve   Rogers    SteveRogers@gmail.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
newdf.sort_index(inplace = True)
print(newdf)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3  Steve   Rogers    SteveRogers@gmail.com
# 4  Bruce   Banner    BruceBanner@email.com

# %%
survey["SalaryUSDYearly"].median()
# Out:
# 74963.0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-241aff9a0e1f> in <cell line: 1>()
# ----> 1 countrygrp = survey.groupby(["Country"])
#
# NameError: name 'survey' is not defined

# %%
survey = pd.read_csv("/content/sample_data/survey_results_public.csv")
countrygrp = survey.groupby(["Country"])
countrygrp.get_group('India')
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# 89121       89122  I agree  I am not primarily a developer, but I write co...
# 89164       89165  I agree                     I am a developer by profession
# 89165       89166  I agree                     I am a developer by profession
# 89167       89168  I agree                     I am a developer by profession
#
# ...

# %%
countrygrp["RemoteWork"].value_counts()
# Out:
# Country      RemoteWork
# Afghanistan  Hybrid (some remote, some in-person)    17
#              Remote                                  17
#              In-person                                8
# Albania      Hybrid (some remote, some in-person)    18
#              In-person                               17
#                                                      ..
# Zambia       Hybrid (some remote, some in-person)     5
#              Remote                                   3
# Zimbabwe     Remote                                   7
#              Hybrid (some remote, some in-person)     5
#              In-person                                5
# Name: count, Length: 490, dtype: int64

# %%
countrygrp["RemoteWork"].value_counts().loc["Belgium"]
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    522
# In-person                               109
# Remote                                   95
# Name: count, dtype: int64

# %%
survey.loc[(survey["LanguageHaveWorkedWith"].str.contains("Python",na= False)) & (survey["Country"] == "India"), ["Country","LanguageHaveWorkedWith"]]
# Out:
#       Country                             LanguageHaveWorkedWith
# 9       India     HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 105     India          Bash/Shell (all shells);PowerShell;Python
# 135     India               C;C++;Haskell;Java;Kotlin;Python;SQL
# 196     India  Bash/Shell (all shells);Go;JavaScript;Python;T...
# 209     India  Assembly;Bash/Shell (all shells);C;C++;Dart;HT...
# ...       ...                                                ...
# 89105   India  Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScr...
# 89108   India                 Bash/Shell (all shells);Python;SQL
# 89119   India                    Dart;HTML/CSS;JavaScript;Python
# 89121   India                                         Python;SQL
# 89164   India                 Go;HTML/CSS;Java;JavaScript;Python
#
# [2793 rows x 2 columns]

# %%
totalpythonusers = countrygrp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
print(totalpythonusers)
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
total_respondents = survey["Country"].value_counts()
print(total_respondents)
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
pythondf = pd.concat([totalpythonusers,total_respondents],axis = 1)
print(pythondf)
# Out:
#                                       LanguageHaveWorkedWith  count
# Country
# Afghanistan                                               22     64
# Albania                                                   19     60
# Algeria                                                   35     85
# Andorra                                                    5     16
# Angola                                                     4     13
# ...                                                      ...    ...
# Venezuela, Bolivarian Republic of...                      42    106
# Viet Nam                                                 174    390
# Yemen                                                      8     20
# Zambia                                                    11     26
# Zimbabwe                                                  19     34
#
# [185 rows x 2 columns]

# %%
pythondf.rename(columns = {"LanguageHaveWorkedWith" : "PythonUsers","count" : "TotalRespondents"},inplace = True)
pythondf["Percentage"] = round(pythondf["PythonUsers"] / pythondf["TotalRespondents"],3)
print(pythondf.sort_values(by = ["Percentage"], ascending = False).head(100))
# Out:
#                            PythonUsers  TotalRespondents  Percentage
# Country
# Congo, Republic of the...            2                 2       1.000
# Dominica                             2                 2       1.000
# Grenada                              1                 1       1.000
# San Marino                           1                 1       1.000
# Samoa                                1                 1       1.000
# ...                                ...               ...         ...
# Paraguay                            19                42       0.452
# Malaysia                           119               264       0.451
# Sweden                             739              1641       0.450
# Portugal                           336               749       0.449
# Viet Nam                           174               390       0.446
#
# [100 rows x 3 columns]

# %%
survey["YearsCode"].unique()
# Out:
# array([nan, '18', '27', '12', '6', '21', '4', '5', '20', '14', '10', '15',
#        '11', '3', '24', '8', '13', 'Less than 1 year', '16', '33', '22',
#        '30', '32', '7', '35', '28', '40', '17', '29', '19',
#        'More than 50 years', '9', '38', '26', '34', '25', '2', '45', '23',
#        '31', '43', '1', '48', '41', '50', '39', '42', '37', '36', '44',
#        '46', '49', '47'], dtype=object)

# %%
survey["YearsCode"].replace("Less than 1 year",1,inplace = True)
survey["YearsCode"].replace("More than 50 years",50,inplace = True)

survey["YearsCode"].unique()
survey["YearsCode"].astype(float)
# Out:
# 0         NaN
# 1        18.0
# 2        27.0
# 3        12.0
# 4         6.0
#          ...
# 89179    20.0
# 89180     5.0
# 89181    10.0
# 89182     3.0
# 89183    17.0
# Name: YearsCode, Length: 89184, dtype: float64

# %%
survey['YearsCode'] = pd.to_numeric(survey['YearsCode'], errors='coerce')

survey["YearsCode"].mean()
# Out:
# 13.973889174815577

# %% [markdown]
# Time Data Handling

# %%
timedf = pd.read_csv("/content/sample_data/KaggleV2-May-2016.csv")
timedf.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
from datetime import datetime

# %%
timedf["ScheduledDay"] = pd.to_datetime(timedf["ScheduledDay"], format = "%Y-%m-%dT%H:%M:%SZ")
print(timedf["ScheduledDay"] )
# Out:
# 0        2016-04-29 18:38:08
# 1        2016-04-29 16:08:27
# 2        2016-04-29 16:19:04
# 3        2016-04-29 17:29:31
# 4        2016-04-29 16:07:23
#                  ...
# 110522   2016-05-03 09:15:35
# 110523   2016-05-03 07:27:33
# 110524   2016-04-27 16:03:52
# 110525   2016-04-27 15:09:23
# 110526   2016-04-27 13:30:56
# Name: ScheduledDay, Length: 110527, dtype: datetime64[ns]

# %%
timedf.loc[0,("ScheduledDay")].day_name()
# Out:
# 'Friday'

# %%
# TO load the datetime during loading of data

timedf2 = pd.read_csv("/content/sample_data/KaggleV2-May-2016.csv",parse_dates= ["ScheduledDay","AppointmentDay"])

# %%
timedf["ScheduledDay"].dt.day_name()
# Out:
# 0            Friday
# 1            Friday
# 2            Friday
# 3            Friday
# 4            Friday
#             ...
# 110522      Tuesday
# 110523      Tuesday
# 110524    Wednesday
# 110525    Wednesday
# 110526    Wednesday
# Name: ScheduledDay, Length: 110527, dtype: object

# %%
print(timedf["ScheduledDay"].min())
print(timedf["ScheduledDay"].max())
print(timedf["ScheduledDay"].max()-timedf["ScheduledDay"].min())
# Out:
# 2015-11-10 07:13:56
# 2016-06-08 20:07:23
# 211 days 12:53:27

# %%
timedf.loc[(timedf["ScheduledDay"] <= '2016') & (timedf["ScheduledDay"] > '2015-11-10'),("ScheduledDay")]
# Out:
# 3764     2015-11-10 07:13:56
# 27389    2015-12-14 08:01:54
# 27390    2015-12-08 13:30:21
# 27391    2015-12-08 13:58:50
# 27392    2015-12-08 14:18:39
#                  ...
# 102819   2015-12-15 10:25:40
# 102868   2015-12-08 14:42:31
# 102870   2015-12-15 10:19:31
# 102871   2015-12-08 14:41:08
# 102872   2015-12-15 10:15:50
# Name: ScheduledDay, Length: 62, dtype: datetime64[ns]
